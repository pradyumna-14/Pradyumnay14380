# %%
#PCA(Principle component analysis)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r"C:\Users\91808\Downloads\wine.csv")
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score

# %%
df.shape
# Out:
# (178, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
df.describe()
# Out:
#              Type     Alcohol       Malic         Ash  Alcalinity   Magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins       Color  \
# count  178.000000  178.000000     178.000000       178.000000  178.000000
# mean     2.295112    2.029270       0.361854         1.590899    5.058090
# ...

# %%
df.columns
# Out:
# Index(['Type', 'Alcohol', 'Malic', 'Ash', 'Alcalinity', 'Magnesium', 'Phenols',
#        'Flavanoids', 'Nonflavanoids', 'Proanthocyanins', 'Color', 'Hue',
#        'Dilution', 'Proline'],
#       dtype='object')

# %%
# histogram Plots
df.hist(bins=30, figsize=(12, 10))
plt.suptitle("Feature Distributions")
plt.show()

# %%
# Box Plots
df.plot(kind='box', subplots=True, layout=(4, 4), figsize=(14, 10), sharex=False)
plt.tight_layout()
plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Feature Correlation Matrix")
plt.show()

# %%
scaler = StandardScaler()
scaled = scaler.fit_transform(df)

# %%
pca = PCA()
pca_data = pca.fit_transform(scaled)

# %%
explained_variance = np.cumsum(pca.explained_variance_ratio_)
plt.plot(range(1, len(explained_variance) + 1), explained_variance, marker='o')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Scree Plot')
plt.grid()
plt.show()

# %%
n_components = 2
pca = PCA(n_components=n_components)
pca_data_reduced = pca.fit_transform(scaled)
kmeans_original = KMeans(n_clusters=3, random_state=42)
original_labels = kmeans_original.fit_predict(scaled)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
print("Silhouette Score (Original):", silhouette_score(scaled, original_labels))
print("Davies-Bouldin Index (Original):", davies_bouldin_score(scaled, original_labels))
# Out:
# Silhouette Score (Original): 0.30648398324833453
# Davies-Bouldin Index (Original): 1.315707552261773

# %%
plt.scatter(scaled[:, 0], scaled[:, 1], c=original_labels, cmap='viridis')
plt.title("K-Means Clusters (Original Data)")
plt.show()

# %%
kmeans_pca = KMeans(n_clusters=3, random_state=42)
pca_labels = kmeans_pca.fit_predict(pca_data_reduced)

# Evaluate
print("Silhouette Score (PCA):", silhouette_score(pca_data_reduced, pca_labels))
print("Davies-Bouldin Index (PCA):", davies_bouldin_score(pca_data_reduced, pca_labels))
# Out:
# Silhouette Score (PCA): 0.6024415520362845
# Davies-Bouldin Index (PCA): 0.5397078562575711
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.scatter(pca_data_reduced[:, 0], pca_data_reduced[:, 1], c=pca_labels, cmap='Set2')
plt.title("K-Means Clusters (PCA Data)")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.grid()
plt.show()

# %%
df['Original_Cluster'] = original_labels
df['PCA_Cluster'] = pca_labels

# %%
# PCA Results:

# Principal Component Analysis (PCA) significantly reduced the dataset's dimensionality while retaining most of the variance.

# The first 2–3 principal components captured a large proportion of the total variance, making them suitable for visualization and clustering.

# PCA helped reveal the underlying structure in the data, showing clearer separation between clusters compared to the raw data.

# Clustering Performance:

# K-Means on the original dataset yielded acceptable results but was somewhat influenced by high-dimensional noise.

# Clustering on PCA-transformed data improved performance metrics (e.g., silhouette score, DB index), indicating better-defined clusters in reduced dimensions.

# Visualizations showed that clusters in PCA space were more compact and separated.

# Cluster Interpretability:

# Clusters could be interpreted based on dominant feature contributions to the principal components, aiding in understanding customer/user segmentation (if applicable).
