# %%
import pandas as pd
# Load dataset

# %%
salesd=pd.read_csv(r"C:\Users\91808\OneDrive\Pictures\Desktop\sales_data_with_discounts.csv")
salesd
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
salesd.columns
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'Volume', 'BU', 'Brand', 'Model',
#        'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
#identify numerical columns
numerical_cols = salesd.select_dtypes(include=['number']).columns

# %%
# Compute basic statistics
stats_summary = salesd[numerical_cols].agg(['mean', 'median', 'std', 'min', 'max', 'count']).T

# %%
# Compute mode separately since it may return multiple values
mode = salesd[numerical_cols].mode().iloc[0]
stats_summary['mode'] = mode

# %%
# Display results
print("Descriptive Statistics for Numerical Columns:")
print(stats_summary)
# Out:
# Descriptive Statistics for Numerical Columns:
#                            mean       median           std         min  \
# Volume                 5.066667     4.000000      4.231602    1.000000
# Avg Price          10453.433333  1450.000000  18079.904840  290.000000
# Total Sales Value  33812.835556  5700.000000  50535.074173  400.000000
# Discount Rate (%)     15.155242    16.577766      4.220602    5.007822
# Discount Amount     3346.499424   988.933733   4509.902963   69.177942
# Net Sales Value    30466.336131  4677.788059  46358.656624  326.974801
#
#                              max  count          mode
# Volume                 31.000000  450.0      3.000000
# Avg Price           60100.000000  450.0    400.000000
# Total Sales Value  196400.000000  450.0  24300.000000
# Discount Rate (%)      19.992407  450.0      5.007822
# Discount Amount     25738.022194  450.0     69.177942
# Net Sales Value    179507.479049  450.0    326.974801

# %%
# Interpretation (Example)
for col in numerical_cols:
    print(f"\nColumn: {col}")
    print(f"Mean: {stats_summary.loc[col, 'mean']:.2f} (Average value)")
    print(f"Median: {stats_summary.loc[col, 'median']:.2f} (Middle value)")
    print(f"Mode: {stats_summary.loc[col, 'mode']:.2f} (Most frequent value)")
    print(f"Std Dev: {stats_summary.loc[col, 'std']:.2f} (Spread of data)")
# Out:
# Column: Volume
# Mean: 5.07 (Average value)
# Median: 4.00 (Middle value)
# Mode: 3.00 (Most frequent value)
# Std Dev: 4.23 (Spread of data)
#
# Column: Avg Price
# Mean: 10453.43 (Average value)
# Median: 1450.00 (Middle value)
# Mode: 400.00 (Most frequent value)
# Std Dev: 18079.90 (Spread of data)
#
# Column: Total Sales Value
# Mean: 33812.84 (Average value)
# Median: 5700.00 (Middle value)
# Mode: 24300.00 (Most frequent value)
# Std Dev: 50535.07 (Spread of data)
#
# Column: Discount Rate (%)
# Mean: 15.16 (Average value)
# Median: 16.58 (Middle value)
# Mode: 5.01 (Most frequent value)
# Std Dev: 4.22 (Spread of data)
#
# Column: Discount Amount
# Mean: 3346.50 (Average value)
# Median: 988.93 (Middle value)
# Mode: 69.18 (Most frequent value)
# Std Dev: 4509.90 (Spread of data)
#
# Column: Net Sales Value
# Mean: 30466.34 (Average value)
# Median: 4677.79 (Middle value)
# Mode: 326.97 (Most frequent value)
# Std Dev: 46358.66 (Spread of data)

# %%
#Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns
# Histograms for numerical columns

# %%
# Histograms for numerical columns
for col in numerical_cols:
    plt.figure(figsize=(8, 5))
    sns.histplot(salesd[col], bins=30, kde=True)
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
# Boxplots for numerical columns
for col in numerical_cols:
    plt.figure(figsize=(8, 5))
    sns.boxplot(y=salesd[col])
    plt.title(f'Boxplot of {col}')
    plt.ylabel(col)
    plt.show()

# %%
# Bar charts for categorical columns
for col in numerical_cols:
    plt.figure(figsize=(10, 5))
    sns.countplot(x=salesd[col], order=salesd[col].value_counts().index)
    plt.title(f'Bar Chart of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Standardization of Numerical Variables
scaler = StandardScaler()
data_scaled = salesd.copy()
data_scaled[numerical_cols] = scaler.fit_transform(salesd[numerical_cols])

print("\nStandardized Numerical Data:")
print(data_scaled[numerical_cols].head())
# Out:
# Standardized Numerical Data:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0  2.350029   0.091173           2.925721          -0.830289         3.952816
# 1  1.167129  -0.019570           1.330995          -0.852661         1.849014
# 2  0.457388   0.312659           1.562775          -1.351631         1.622995
# 3  0.220808   0.534146           1.719276          -1.949723         1.113807
# 4 -0.488932  -0.130313          -0.188452           0.673739         0.227852
#
#    Net Sales Value
# 0         2.804756
# 1         1.271026
# 2         1.545675
# 3         1.765810
# 4        -0.227595

# %%
# One-Hot Encoding for Categorical Variables
data_encoded = pd.get_dummies(data_scaled, columns=numerical_cols, drop_first=True)

print("\nDataset after One-Hot Encoding:")
print(data_encoded.head())
# Out:
# Dataset after One-Hot Encoding:
#          Date       Day  SKU City       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C  Mobiles   YouM      YM-98
#
#    Volume_-0.7255123425579885  Volume_-0.48893223085429655  \
# 0                       False                        False
# 1                       False                        False
# 2                       False                        False
# 3                       False                        False
# 4                       False                         True
#
#    Volume_-0.2523521191506046  ...  Net Sales Value_2.705753372693231  \
# 0                       False  ...                              False
# ...

# %%
# Conclusion
print("\nKey Findings:")
print("1. Descriptive analytics helped in understanding data distribution, central tendency, and variability.")
print("2. Data visualization provided insights into patterns, outliers, and categorical distributions.")
print("3. Standardization ensured numerical features have a mean of 0 and standard deviation of 1, making them suitable for ML models.")
print("4. One-hot encoding converted categorical variables into numerical format, allowing ML models to interpret them.")
print("5. These preprocessing steps improve data quality and model performance.")
# Out:
# Key Findings:
# 1. Descriptive analytics helped in understanding data distribution, central tendency, and variability.
# 2. Data visualization provided insights into patterns, outliers, and categorical distributions.
# 3. Standardization ensured numerical features have a mean of 0 and standard deviation of 1, making them suitable for ML models.
# 4. One-hot encoding converted categorical variables into numerical format, allowing ML models to interpret them.
# 5. These preprocessing steps improve data quality and model performance.
